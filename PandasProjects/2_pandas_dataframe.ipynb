# %%
import numpy as np

# %%
import pandas as pd

# %% [markdown]
# ## random.randn(x,y)

# %%
data = np.random.randn(4,3)

# %%
data
# Out:
# array([[ 0.65972188, -0.12479104,  0.351886  ],
#        [ 0.61847569,  0.65506085,  0.24869934],
#        [-1.92780667,  0.81806697, -0.1857992 ],
#        [ 0.44536429, -1.38376365,  0.8165482 ]])

# %%
# data.Series(data)
# AttributeError: 'numpy.ndarray' object has no attribute 'Series'

# %%
data_frame=pd.DataFrame(data)

# %%
data_frame
# Out:
#           0         1         2
# 0  0.659722 -0.124791  0.351886
# 1  0.618476  0.655061  0.248699
# 2 -1.927807  0.818067 -0.185799
# 3  0.445364 -1.383764  0.816548

# %%
type(data_frame)
# Out:
# pandas.core.frame.DataFrame

# %%
type(data_frame[0])
# Out:
# pandas.core.series.Series

# %%
new_df = pd.DataFrame(data, index=["Atil", "Zeynep", "Atlas", "Mehmet"], columns=["Salary", "Age", "Seniority"])

# %%
new_df
# Out:
#           Salary       Age  Seniority
# Atil    0.659722 -0.124791   0.351886
# Zeynep  0.618476  0.655061   0.248699
# Atlas  -1.927807  0.818067  -0.185799
# Mehmet  0.445364 -1.383764   0.816548

# %%
new_df["Salary"]
# Out:
# Atil      0.659722
# Zeynep    0.618476
# Atlas    -1.927807
# Mehmet    0.445364
# Name: Salary, dtype: float64

# %%
new_df[["Salary","Age"]]
# Out:
#           Salary       Age
# Atil    0.659722 -0.124791
# Zeynep  0.618476  0.655061
# Atlas  -1.927807  0.818067
# Mehmet  0.445364 -1.383764

# %% [markdown]
# ## loc: get row with index name

# %%
new_df.loc["Atil"] # loc: get column with index name
# Out:
# Salary       0.659722
# Age         -0.124791
# Seniority    0.351886
# Name: Atil, dtype: float64

# %% [markdown]
# ## iloc: get ro with index(i)

# %%
new_df.iloc[0] # iloc: get row with index(i)
# Out:
# Salary       0.659722
# Age         -0.124791
# Seniority    0.351886
# Name: Atil, dtype: float64

# %%
new_df
# Out:
#           Salary       Age  Seniority
# Atil    0.659722 -0.124791   0.351886
# Zeynep  0.618476  0.655061   0.248699
# Atlas  -1.927807  0.818067  -0.185799
# Mehmet  0.445364 -1.383764   0.816548

# %%
new_df.iloc[:,0] # : (all row),  0 (0. index column)
# Out:
# Atil      0.659722
# Zeynep    0.618476
# Atlas    -1.927807
# Mehmet    0.445364
# Name: Salary, dtype: float64

# %%
new_df.iloc[:,2]
# Out:
# Atil      0.351886
# Zeynep    0.248699
# Atlas    -0.185799
# Mehmet    0.816548
# Name: Seniority, dtype: float64

# %%
new_df["Extra"]=10

# %%
new_df
# Out:
#           Salary       Age  Seniority  Extra
# Atil    0.659722 -0.124791   0.351886     10
# Zeynep  0.618476  0.655061   0.248699     10
# Atlas  -1.927807  0.818067  -0.185799     10
# Mehmet  0.445364 -1.383764   0.816548     10

# %% [markdown]
# ## drop

# %%
new_df.drop("Extra", axis=1) # 1: column, 0: row
# Out:
#           Salary       Age  Seniority
# Atil    0.659722 -0.124791   0.351886
# Zeynep  0.618476  0.655061   0.248699
# Atlas  -1.927807  0.818067  -0.185799
# Mehmet  0.445364 -1.383764   0.816548

# %%
new_df # Extra not reel drop
# Out:
#           Salary       Age  Seniority  Extra
# Atil    0.659722 -0.124791   0.351886     10
# Zeynep  0.618476  0.655061   0.248699     10
# Atlas  -1.927807  0.818067  -0.185799     10
# Mehmet  0.445364 -1.383764   0.816548     10

# %% [markdown]
# ## inplace: for reel drop

# %%
new_df.drop("Extra", axis=1,inplace=True)

# %%
new_df
# Out:
#           Salary       Age  Seniority
# Atil    0.659722 -0.124791   0.351886
# Zeynep  0.618476  0.655061   0.248699
# Atlas  -1.927807  0.818067  -0.185799
# Mehmet  0.445364 -1.383764   0.816548

# %%
new_df["Mehmet"]=10

# %%
new_df
# Out:
#           Salary       Age  Seniority  Mehmet
# Atil    0.659722 -0.124791   0.351886      10
# Zeynep  0.618476  0.655061   0.248699      10
# Atlas  -1.927807  0.818067  -0.185799      10
# Mehmet  0.445364 -1.383764   0.816548      10

# %%
new_df.drop("Mehmet", axis=1,inplace=True)

# %%
new_df
# Out:
#           Salary       Age  Seniority
# Atil    0.659722 -0.124791   0.351886
# Zeynep  0.618476  0.655061   0.248699
# Atlas  -1.927807  0.818067  -0.185799
# Mehmet  0.445364 -1.383764   0.816548

# %%
new_df.drop("Mehmet", axis=0)
# Out:
#           Salary       Age  Seniority
# Atil    0.659722 -0.124791   0.351886
# Zeynep  0.618476  0.655061   0.248699
# Atlas  -1.927807  0.818067  -0.185799

# %%
new_df
# Out:
#           Salary       Age  Seniority
# Atil    0.659722 -0.124791   0.351886
# Zeynep  0.618476  0.655061   0.248699
# Atlas  -1.927807  0.818067  -0.185799
# Mehmet  0.445364 -1.383764   0.816548

# %%
new_df.loc["Atlas"]
# Out:
# Salary      -1.927807
# Age          0.818067
# Seniority   -0.185799
# Name: Atlas, dtype: float64

# %%
new_df.loc["Atlas"]["Salary"]
# Out:
# -1.9278066665725724

# %%
new_df.loc["Atlas","Salary"]
# Out:
# -1.9278066665725724

# %%
new_df.loc["Atlas","Salary"]=100

# %%
new_df
# Out:
#             Salary       Age  Seniority
# Atil      0.659722 -0.124791   0.351886
# Zeynep    0.618476  0.655061   0.248699
# Atlas   100.000000  0.818067  -0.185799
# Mehmet    0.445364 -1.383764   0.816548

# %%
new_df>0
# Out:
#         Salary    Age  Seniority
# Atil      True  False       True
# Zeynep    True   True       True
# Atlas     True   True      False
# Mehmet    True  False       True

# %%
boolean_frame=new_df>0

# %%
new_df[boolean_frame]
# Out:
#             Salary       Age  Seniority
# Atil      0.659722       NaN   0.351886
# Zeynep    0.618476  0.655061   0.248699
# Atlas   100.000000  0.818067        NaN
# Mehmet    0.445364       NaN   0.816548

# %%
new_df[new_df>0]
# Out:
#             Salary       Age  Seniority
# Atil      0.659722       NaN   0.351886
# Zeynep    0.618476  0.655061   0.248699
# Atlas   100.000000  0.818067        NaN
# Mehmet    0.445364       NaN   0.816548

# %%
new_df[new_df["Salary"]>1]
# Out:
#        Salary       Age  Seniority
# Atlas   100.0  0.818067  -0.185799

# %%
new_df
# Out:
#             Salary       Age  Seniority
# Atil      0.659722 -0.124791   0.351886
# Zeynep    0.618476  0.655061   0.248699
# Atlas   100.000000  0.818067  -0.185799
# Mehmet    0.445364 -1.383764   0.816548

# %%
new_df[new_df["Age"]>0]
# Out:
#             Salary       Age  Seniority
# Zeynep    0.618476  0.655061   0.248699
# Atlas   100.000000  0.818067  -0.185799

# %%
new_df
# Out:
#             Salary       Age  Seniority
# Atil      0.659722 -0.124791   0.351886
# Zeynep    0.618476  0.655061   0.248699
# Atlas   100.000000  0.818067  -0.185799
# Mehmet    0.445364 -1.383764   0.816548

# %% [markdown]
# ## reset_index()

# %%
reset_frame=new_df.reset_index()

# %%
reset_frame
# Out:
#     index      Salary       Age  Seniority
# 0    Atil    0.659722 -0.124791   0.351886
# 1  Zeynep    0.618476  0.655061   0.248699
# 2   Atlas  100.000000  0.818067  -0.185799
# 3  Mehmet    0.445364 -1.383764   0.816548

# %%
reset_frame.loc[0]
# Out:
# index            Atil
# Salary       0.659722
# Age         -0.124791
# Seniority    0.351886
# Name: 0, dtype: object

# %%
new_indeces=["Ati","Zey","Atl", "Meh"]

# %%
new_df["NewIndex"]=new_indeces

# %%
new_df
# Out:
#             Salary       Age  Seniority NewIndex
# Atil      0.659722 -0.124791   0.351886      Ati
# Zeynep    0.618476  0.655061   0.248699      Zey
# Atlas   100.000000  0.818067  -0.185799      Atl
# Mehmet    0.445364 -1.383764   0.816548      Meh

# %% [markdown]
# ## set_index()

# %%
new_df.set_index("NewIndex", inplace=True)

# %%
new_df
# Out:
#               Salary       Age  Seniority
# NewIndex
# Ati         0.659722 -0.124791   0.351886
# Zey         0.618476  0.655061   0.248699
# Atl       100.000000  0.818067  -0.185799
# Meh         0.445364 -1.383764   0.816548

# %%
new_df.loc["Ati"]
# Out:
# Salary       0.659722
# Age         -0.124791
# Seniority    0.351886
# Name: Ati, dtype: float64

# %% [markdown]
# # Multi Index

# %%
first_index=["Simpson","Simpson","Simpson", "South Park","South Park","South Park"]

# %%
inner_index=["Homer","Bart","Marge", "Cartman","Kenny", "Kyle"]

# %%
zipped_index=list(zip(first_index, inner_index))

# %%
zipped_index
# Out:
# [('Simpson', 'Homer'),
#  ('Simpson', 'Bart'),
#  ('Simpson', 'Marge'),
#  ('South Park', 'Cartman'),
#  ('South Park', 'Kenny'),
#  ('South Park', 'Kyle')]

# %%
zipped_index= pd.MultiIndex.from_tuples(zipped_index)

# %%
zipped_index
# Out:
# MultiIndex([(   'Simpson',   'Homer'),
#             (   'Simpson',    'Bart'),
#             (   'Simpson',   'Marge'),
#             ('South Park', 'Cartman'),
#             ('South Park',   'Kenny'),
#             ('South Park',    'Kyle')],
#            )

# %%
sample_values=np.ones((6,2))

# %%
big_df=pd.DataFrame(sample_values,index=zipped_index, columns=["Age", "Salary"])

# %%
big_df
# Out:
#                     Age  Salary
# Simpson    Homer    1.0     1.0
#            Bart     1.0     1.0
#            Marge    1.0     1.0
# South Park Cartman  1.0     1.0
#            Kenny    1.0     1.0
#            Kyle     1.0     1.0

# %%
big_df["Age"]
# Out:
# Simpson     Homer      1.0
#             Bart       1.0
#             Marge      1.0
# South Park  Cartman    1.0
#             Kenny      1.0
#             Kyle       1.0
# Name: Age, dtype: float64

# %%
#big_df.loc["Homer"] #KeyError: 'Homer'

# %%
big_df.loc["Simpson"].loc["Homer"]
# Out:
# Age       1.0
# Salary    1.0
# Name: Homer, dtype: float64
