# %%
import numpy as np

# %%
import pandas as pd

# %%
data = np.random.randn(4,3)

# %%
data
# Out:
# array([[ 1.25785449, -1.42643445,  0.31338395],
#        [ 1.24688665,  1.73455978, -3.96414067],
#        [-2.06002753,  1.03256462, -0.55226968],
#        [-0.36161012, -0.10398709, -0.13433857]])

# %%
# data.Series(data)
# AttributeError: 'numpy.ndarray' object has no attribute 'Series'

# %%
data_frame=pd.DataFrame(data)

# %%
data_frame
# Out:
#           0         1         2
# 0  1.257854 -1.426434  0.313384
# 1  1.246887  1.734560 -3.964141
# 2 -2.060028  1.032565 -0.552270
# 3 -0.361610 -0.103987 -0.134339

# %%
type(data_frame)
# Out:
# pandas.core.frame.DataFrame

# %%
type(data_frame[0])
# Out:
# pandas.core.series.Series

# %%
new_df = pd.DataFrame(data, index=["Atil", "Zeynep", "Atlas", "Mehmet"], columns=["Salary", "Age", "Seniority"])

# %%
new_df
# Out:
#           Salary       Age  Seniority
# Atil    1.257854 -1.426434   0.313384
# Zeynep  1.246887  1.734560  -3.964141
# Atlas  -2.060028  1.032565  -0.552270
# Mehmet -0.361610 -0.103987  -0.134339

# %%
new_df["Salary"]
# Out:
# Atil      1.257854
# Zeynep    1.246887
# Atlas    -2.060028
# Mehmet   -0.361610
# Name: Salary, dtype: float64

# %%
new_df[["Salary","Age"]]
# Out:
#           Salary       Age
# Atil    1.257854 -1.426434
# Zeynep  1.246887  1.734560
# Atlas  -2.060028  1.032565
# Mehmet -0.361610 -0.103987

# %%
new_df.loc["Atil"] # loc: get column with index name
# Out:
# Salary       1.257854
# Age         -1.426434
# Seniority    0.313384
# Name: Atil, dtype: float64

# %%
new_df.iloc[0] # iloc: get column with index(i)
# Out:
# Salary       1.257854
# Age         -1.426434
# Seniority    0.313384
# Name: Atil, dtype: float64

# %%
new_df
# Out:
#           Salary       Age  Seniority
# Atil    1.257854 -1.426434   0.313384
# Zeynep  1.246887  1.734560  -3.964141
# Atlas  -2.060028  1.032565  -0.552270
# Mehmet -0.361610 -0.103987  -0.134339

# %%
new_df.iloc[:,0] # : (all row),  0 (0. index column)
# Out:
# Atil      1.257854
# Zeynep    1.246887
# Atlas    -2.060028
# Mehmet   -0.361610
# Name: Salary, dtype: float64

# %%
new_df.iloc[:,2]
# Out:
# Atil      0.313384
# Zeynep   -3.964141
# Atlas    -0.552270
# Mehmet   -0.134339
# Name: Seniority, dtype: float64

# %%
new_df["Extra"]=10

# %%
new_df
# Out:
#           Salary       Age  Seniority  Extra
# Atil    1.257854 -1.426434   0.313384     10
# Zeynep  1.246887  1.734560  -3.964141     10
# Atlas  -2.060028  1.032565  -0.552270     10
# Mehmet -0.361610 -0.103987  -0.134339     10

# %%
new_df.drop("Extra", axis=1) # 1: column, 0: row
# Out:
#           Salary       Age  Seniority
# Atil    1.257854 -1.426434   0.313384
# Zeynep  1.246887  1.734560  -3.964141
# Atlas  -2.060028  1.032565  -0.552270
# Mehmet -0.361610 -0.103987  -0.134339

# %%
new_df # Extra not reel drop
# Out:
#           Salary       Age  Seniority  Extra
# Atil    1.257854 -1.426434   0.313384     10
# Zeynep  1.246887  1.734560  -3.964141     10
# Atlas  -2.060028  1.032565  -0.552270     10
# Mehmet -0.361610 -0.103987  -0.134339     10

# %%
new_df.drop("Extra", axis=1,inplace=True) # inplace: for reel drop

# %%
new_df
# Out:
#           Salary       Age  Seniority
# Atil    1.257854 -1.426434   0.313384
# Zeynep  1.246887  1.734560  -3.964141
# Atlas  -2.060028  1.032565  -0.552270
# Mehmet -0.361610 -0.103987  -0.134339

# %%
new_df["Mehmet"]=10

# %%
new_df
# Out:
#           Salary       Age  Seniority  Mehmet
# Atil    1.257854 -1.426434   0.313384      10
# Zeynep  1.246887  1.734560  -3.964141      10
# Atlas  -2.060028  1.032565  -0.552270      10
# Mehmet -0.361610 -0.103987  -0.134339      10

# %%
new_df.drop("Mehmet", axis=1,inplace=True)

# %%
new_df
# Out:
#           Salary       Age  Seniority
# Atil    1.257854 -1.426434   0.313384
# Zeynep  1.246887  1.734560  -3.964141
# Atlas  -2.060028  1.032565  -0.552270
# Mehmet -0.361610 -0.103987  -0.134339

# %%
new_df.drop("Mehmet", axis=0)
# Out:
#           Salary       Age  Seniority
# Atil    1.257854 -1.426434   0.313384
# Zeynep  1.246887  1.734560  -3.964141
# Atlas  -2.060028  1.032565  -0.552270

# %%
new_df
# Out:
#           Salary       Age  Seniority
# Atil    1.257854 -1.426434   0.313384
# Zeynep  1.246887  1.734560  -3.964141
# Atlas  -2.060028  1.032565  -0.552270
# Mehmet -0.361610 -0.103987  -0.134339

# %%
new_df.loc["Atlas"]
# Out:
# Salary      -2.060028
# Age          1.032565
# Seniority   -0.552270
# Name: Atlas, dtype: float64

# %%
new_df.loc["Atlas"]["Salary"]
# Out:
# -2.0600275347905463

# %%
new_df.loc["Atlas","Salary"]
# Out:
# -2.0600275347905463

# %%
new_df.loc["Atlas","Salary"]=100

# %%
new_df
# Out:
#             Salary       Age  Seniority
# Atil      1.257854 -1.426434   0.313384
# Zeynep    1.246887  1.734560  -3.964141
# Atlas   100.000000  1.032565  -0.552270
# Mehmet   -0.361610 -0.103987  -0.134339

# %%
new_df>0
# Out:
#         Salary    Age  Seniority
# Atil      True  False       True
# Zeynep    True   True      False
# Atlas     True   True      False
# Mehmet   False  False      False

# %%
boolean_frame=new_df>0

# %%
new_df[boolean_frame]
# Out:
#             Salary       Age  Seniority
# Atil      1.257854       NaN   0.313384
# Zeynep    1.246887  1.734560        NaN
# Atlas   100.000000  1.032565        NaN
# Mehmet         NaN       NaN        NaN

# %%
new_df[new_df>0]
# Out:
#             Salary       Age  Seniority
# Atil      1.257854       NaN   0.313384
# Zeynep    1.246887  1.734560        NaN
# Atlas   100.000000  1.032565        NaN
# Mehmet         NaN       NaN        NaN

# %%
new_df[new_df["Salary"]>1]
# Out:
#             Salary       Age  Seniority
# Atil      1.257854 -1.426434   0.313384
# Zeynep    1.246887  1.734560  -3.964141
# Atlas   100.000000  1.032565  -0.552270

# %%
new_df
# Out:
#             Salary       Age  Seniority
# Atil      1.257854 -1.426434   0.313384
# Zeynep    1.246887  1.734560  -3.964141
# Atlas   100.000000  1.032565  -0.552270
# Mehmet   -0.361610 -0.103987  -0.134339

# %%
new_df[new_df["Age"]>0]
# Out:
#             Salary       Age  Seniority
# Zeynep    1.246887  1.734560  -3.964141
# Atlas   100.000000  1.032565  -0.552270

# %%
new_df
# Out:
#             Salary       Age  Seniority
# Atil      1.257854 -1.426434   0.313384
# Zeynep    1.246887  1.734560  -3.964141
# Atlas   100.000000  1.032565  -0.552270
# Mehmet   -0.361610 -0.103987  -0.134339

# %%
reset_frame=new_df.reset_index()

# %%
reset_frame
# Out:
#     index      Salary       Age  Seniority
# 0    Atil    1.257854 -1.426434   0.313384
# 1  Zeynep    1.246887  1.734560  -3.964141
# 2   Atlas  100.000000  1.032565  -0.552270
# 3  Mehmet   -0.361610 -0.103987  -0.134339

# %%
reset_frame.loc[0]
# Out:
# index            Atil
# Salary       1.257854
# Age         -1.426434
# Seniority    0.313384
# Name: 0, dtype: object

# %%
new_indeces=["Ati","Zey","Atl", "Meh"]

# %%
new_df["NewIndex"]=new_indeces

# %%
new_df
# Out:
#             Salary       Age  Seniority NewIndex
# Atil      1.257854 -1.426434   0.313384      Ati
# Zeynep    1.246887  1.734560  -3.964141      Zey
# Atlas   100.000000  1.032565  -0.552270      Atl
# Mehmet   -0.361610 -0.103987  -0.134339      Meh

# %%
new_df.set_index("NewIndex", inplace=True)

# %%
new_df
# Out:
#               Salary       Age  Seniority
# NewIndex
# Ati         1.257854 -1.426434   0.313384
# Zey         1.246887  1.734560  -3.964141
# Atl       100.000000  1.032565  -0.552270
# Meh        -0.361610 -0.103987  -0.134339

# %%
new_df.loc["Ati"]
# Out:
# Salary       1.257854
# Age         -1.426434
# Seniority    0.313384
# Name: Ati, dtype: float64

# %% [markdown]
# # Multi Index

# %%
first_index=["Simpson","Simpson","Simpson", "South Park","South Park","South Park"]

# %%
inner_index=["Homer","Bart","Marge", "Cartman","Kenny", "Kyle"]

# %%
zipped_index=list(zip(first_index, inner_index))

# %%
zipped_index
# Out:
# [('Simpson', 'Homer'),
#  ('Simpson', 'Bart'),
#  ('Simpson', 'Marge'),
#  ('South Park', 'Cartman'),
#  ('South Park', 'Kenny'),
#  ('South Park', 'Kyle')]

# %%
zipped_index= pd.MultiIndex.from_tuples(zipped_index)

# %%
zipped_index
# Out:
# MultiIndex([(   'Simpson',   'Homer'),
#             (   'Simpson',    'Bart'),
#             (   'Simpson',   'Marge'),
#             ('South Park', 'Cartman'),
#             ('South Park',   'Kenny'),
#             ('South Park',    'Kyle')],
#            )

# %%
sample_values=np.ones((6,2))

# %%
big_df=pd.DataFrame(sample_values,index=zipped_index, columns=["Age", "Salary"])

# %%
big_df
# Out:
#                     Age  Salary
# Simpson    Homer    1.0     1.0
#            Bart     1.0     1.0
#            Marge    1.0     1.0
# South Park Cartman  1.0     1.0
#            Kenny    1.0     1.0
#            Kyle     1.0     1.0

# %%
big_df["Age"]
# Out:
# Simpson     Homer      1.0
#             Bart       1.0
#             Marge      1.0
# South Park  Cartman    1.0
#             Kenny      1.0
#             Kyle       1.0
# Name: Age, dtype: float64

# %%
#big_df["Homer"] #KeyError: 'Homer'

# %%
big_df.loc["Simpson"].loc
["Homer"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Simpson'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[187], line 1
# ----> 1 big_df["Simpson"]["Homer"]
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Simpson'
